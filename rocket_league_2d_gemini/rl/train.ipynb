# %%
# CELL 1: Setup Environment and Clone Repository
# !pip install uv
# !mkdir -p /content/personal_project
# %cd /content/personal_project

# ⚠️ REPLACE THE URL BELOW WITH YOUR ACTUAL GITHUB REPO URL ⚠️
# If your repo is private, use: https://<YOUR_GITHUB_TOKEN>@github.com/Username/Repo.git
# !git clone https://github.com/Luqman-Ansari/Rocket-League-2D.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 70.4 MB/s eta 0:00:00:00:0100:01
# ...
# /content/personal_project
# Cloning into 'Rocket-League-2D'...
# remote: Enumerating objects: 291, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 291 (delta 23), reused 47 (delta 17), pack-reused 237 (from 1)
# Receiving objects: 100% (291/291), 71.90 MiB | 11.82 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# CELL 2: Navigate to your working directory and sync
# %cd /content/personal_project/Rocket-League-2D/rocket_league_2d_gemini

print("Syncing dependencies with uv...")
# !uv sync
# Out:
# /content/personal_project/Rocket-League-2D/rocket_league_2d_gemini
# Syncing dependencies with uv...
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 63 packages in 0.76ms
# Prepared 60 packages in 1m 30s
# Installed 60 packages in 899ms
#  + absl-py==2.4.0
#  + ale-py==0.11.2
#  + cloudpickle==3.1.2
#  + contourpy==1.3.3
#  + cuda-bindings==12.9.4
#  + cuda-pathfinder==1.4.0
#  + cycler==0.12.1
#  + farama-notifications==0.0.4
#  + filelock==3.24.3
#  + fonttools==4.61.1
#  + fsspec==2026.2.0
#  + grpcio==1.78.1
#  + gymnasium==1.2.3
#  + jinja2==3.1.6
#  + kiwisolver==1.4.9
#  + markdown==3.10.2
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib==3.10.8
#  + mdurl==0.1.2
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.2
#  + nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cudnn-cu12==9.10.2.21
# ...

# %%
# CELL 3: Train the Model Headlessly
print("Starting training on Colab GPU...")

# We pass SDL_VIDEODRIVER=dummy for Pygame 
# AND we pass MPLBACKEND=agg to fix the Colab Matplotlib crash
# !SDL_VIDEODRIVER=dummy MPLBACKEND=agg make train
# Out:
# Starting training on Colab GPU...
# uv run python -m rl.train
#
# === ROCKET SOCCER AI TRAINING ===
# 1. Initializing Environment...
# 2. Building PPO Brain...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /content/personal_project/Rocket-League-2D/rocket_league_2d_gemini/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# 3. Starting Training for 20000 timesteps...
# ---------------------------------
# ...

# %%
# CELL 4: Download the Trained Model
from google.colab import files
import os

model_path = "rl/versions/v1.zip"

if os.path.exists(model_path):
    print("Training complete! Downloading v1.zip to your laptop...")
    files.download(model_path)
else:
    print(f"Error: Could not find {model_path}. Check the output of Cell 3 to see if training crashed.")
# Out:
# Training complete! Downloading v1.zip to your laptop...
